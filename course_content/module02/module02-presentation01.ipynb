# %% [markdown]
# <img src="https://jupyter.org/assets/main-logo.svg" heigt=60> <font size="14" color=grey>  DHI Campus - Jupyter Training</font>
# ***

# %% [markdown]
# <font size=6> <b> Welcome! <b> </font>
#
# <u>**Summarized learning goals of this Module "Getting data into notebooks"**</u>
#
# After having finished this module you should...
# - understand what Interactive Python and what a **kernel** is
# - know to **import spreadsheet / csv data** into notebook with pandas
# - feel comfortable to **reshape tabular data** (slicing, transposing, pivoting, resampling)
# - **create simple plots** in Python / Jupyter Notebooks

# %% [markdown]
# <u>**Agenda for this module**</u>
# 1. Introduction on how to get data into a Notebook...
# 2. ...and how to get it out of a Notebook.
# 2. How to reformat data.
# 3. How to query or select data
# 4. First steps towards visualization of data
# 5. Feedback and discussion, introduction of homework for next week

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

button = widgets.Button(description="Click to continue with module 2!", 
                        layout=widgets.Layout(width='95%', height='40px'))
output = widgets.Output()

display(button, output)

def on_button_clicked(b):
    with output:
        print("------------------------------ ICEBREAKER! Spot the difference ---------------------")
        img=mpimg.imread('figures/where-is-waldo.jpg')
        fig, ax = plt.subplots(figsize=(12,8))
        im = ax.imshow(img)
        ax.axis('off')
        plt.imshow(img)
        
        
button.on_click(on_button_clicked)
# Out:
# Button(description='Click to continue with module 2!', layout=Layout(height='40px', width='95%'), style=Button…
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

button2 = widgets.Button(description="...And once again: Click to continue with module 2!", 
                        layout=widgets.Layout(width='95%', height='40px'),button_style='danger')
output2 = widgets.Output()

display(button2, output2)

def on_button_clicked2(b):
    with output2:
        img2=mpimg.imread('figures/questions_text.png')
        fig2, ax2 = plt.subplots(figsize=(12,8))
        im2 = ax2.imshow(img2)
        ax2.axis('off')
        plt.imshow(img2)
        
        
button2.on_click(on_button_clicked2)
# Out:
# Button(button_style='danger', description='...And once again: Click to continue with module 2!', layout=Layout…
# Output()

# %%
import random
import ipywidgets as widgets
from IPython.display import display


button3 = widgets.Button(description="?",
                        layout=widgets.Layout(width='95%', height='40px'),
                        button_style='success')
output3 = widgets.Output()

list_participants = ["Shubneet", 
                     "Jose", 
                     "Remi", 
                     "Ebrahim", 
                     "Gregory", 
                     "Lezek", 
                     "Yi Wang", 
                     "Elise", 
                     "Henrik", 
                     "Xue-yi", 
                     "Björn", 
                     "Sophia"]

list_questions = ["What is a kernel?",
                  "Which kernels exist? Name 3",
                  "What is NumPy and its purpose?",
                  "What is Pandas and what is its purpose?"]

display(button3, output3)

count = 0

def on_button_clicked3(b):
    with output3:
        global count
        
        if count < len(list_questions):
            print(random.choice(list_participants)+': '+list_questions[count])
            count = count +1
        elif count == len(list_questions):
            print('Alex and Clemens: Ask if anyone has questions for you')
            count = count +1
        else:
            print('Well done, off to the next guided coding session!')
button3.on_click(on_button_clicked3)
# Out:
# Button(button_style='success', description='?', layout=Layout(height='40px', width='95%'), style=ButtonStyle()…
# Output()

# %% [markdown]
# [Guided coding notebook](module02-guidedcoding02.ipynb)
